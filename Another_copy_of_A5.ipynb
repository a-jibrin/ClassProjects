# %% [markdown]
# <a href="https://colab.research.google.com/github/a-jibrin/ClassProjects/blob/main/Another_copy_of_A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 5: Sentiment Analysis of Movie Reviews
# ### Total Points: 50
#
# The goal of this assignment is to make you familiar with classification algorithms.
# Complete the following programming tasks in any language of your preference.

# %% [markdown]
# # Get the Data [5]
# - Get the data from this source https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# - How many rows and columns are there?
# - Take a random sample of 20K reviews.

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('IMDB Dataset.csv')

print(f"Number Rows:", data.shape[0])
print(f"Number Columns:", data.shape[1])
# Out:
# Number Rows: 48419
# Number Columns: 2

# %%
sample_data = data.loc[data.index.isin(data.sample(n=20000, random_state=0).index)]
sample_data
# Out:
#                                                   review sentiment
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# 6      I sure would like to see a resurrection of a u...  positive
# 14     This a fantastic movie of three prisoners who ...  positive
# 15     Kind of drawn in by the erotic scenes, only to...  negative
# ...                                                  ...       ...
# 48405  This movie is a disgrace to the Major League F...  negative
# 48406  A remake of Alejandro Amenabar's Abre los Ojos...  negative
# 48407  When I first tuned in on this morning news, I ...  negative
# 48414  I thought this movie did a down right good job...  positive
# 48418  No one expects the Star Trek movies to be high...  negative
#
# [20000 rows x 2 columns]

# %% [markdown]
# #Text Preprocessing [10]
# - Convert all reviews to lower case.
# - Remove non-alphabetic words or tokens from the reviews.

# %%
data['cleaned_reviews'] = data.review.str.lower()
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                      cleaned_reviews
# 0  one of the other reviewers has mentioned that ...
# 1  a wonderful little production. <br /><br />the...
# 2  i thought this was a wonderful way to spend ti...
# 3  basically there's a family where a little boy ...
# 4  petter mattei's "love in the time of money" is...

# %%
def remove_non_alphabetic_words(string):
    words = string.split()
    words = [w for w in words if w.isalpha() == True]
    return ' '.join(words)

data['cleaned_reviews'] = data.cleaned_reviews.apply(remove_non_alphabetic_words)
data.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                      cleaned_reviews
# 0  one of the other reviewers has mentioned that ...
# 1  a wonderful little filming technique is very v...
# 2  i thought this was a wonderful way to spend ti...
# 3  basically a family where a little boy thinks a...
# 4  petter in the time of is a visually stunning f...

# %% [markdown]
# #Feature Extraction [10]
# Use TfiDfVectorizer to convert the reviews to feature vectors. Use 10K most frequent words/tokens. Remove stopwords.

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import stopwords

vectorizer = TfidfVectorizer(max_features=10000,
                             stop_words=stopwords.words('english'))
X = vectorizer.fit_transform(data.cleaned_reviews)

# %% [markdown]
# # Train Test Split [5]
# - Split the data into train and test with a 75:25 ratio.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, data.sentiment, test_size=0.25, random_state=0)
print("Train Size:", X_train.shape[0])
print("Test Size:", X_test.shape[0])
# Out:
# Train Size: 36314
# Test Size: 12105

# %% [markdown]
# #Algorithm Selection [20]
# - Use Decisiion Trees, K Nearest Neighbors, and Support Vector Classifier to build classification models.
# - Which performs the best in terms of precision and recall? Print classification reports for each of the above algorithms.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

dtclf = DecisionTreeClassifier().fit(X_train, y_train)
dt_pred = dtclf.predict(X_test)

print(classification_report(y_test, dt_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.68      0.70      0.69      5942
#     positive       0.70      0.69      0.70      6163
#
#     accuracy                           0.69     12105
#    macro avg       0.69      0.69      0.69     12105
# weighted avg       0.69      0.69      0.69     12105

# %%
from sklearn.neighbors import KNeighborsClassifier
# K Nearest Neighbors
knnclf = KNeighborsClassifier().fit(X_train, y_train)

knn_pred = knnclf.predict(X_test)
print(classification_report(y_test, knn_pred))

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
# Support Vector Classifier
svcclf = SVC().fit(X_train, y_train)
svc_pred = svcclf.predict(X_test)
print(classification_report(y_test, svc_pred))
